# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager=SpotifyClientCredentials(client_id="86899b28248b466db36a081247e0f272",client_secret="0af3c3241d6144dba4762d38a155f68e")

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link="https://open.spotify.com/playlist/6VOedaf3eNWDOVpa9Qdlvg"

#https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI=playlist_link.split("/")[-1]
playlist_URI
# Out:
# '6VOedaf3eNWDOVpa9Qdlvg'

# %%
data = sp.playlist_tracks(playlist_URI,limit=10, offset=0, market='US')
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6VOedaf3eNWDOVpa9Qdlvg/tracks?offset=0&limit=10&market=US&additional_types=track',
#  'items': [{'added_at': '2024-02-24T05:40:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#     'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#     'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#     'type': 'user',
#     'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/2EuOCirl08WxbRY2cfj4H5',
#      'id': '2EuOCirl08WxbRY2cfj4H5',
#      'images': [{'height': 640,
# ...

# %%
data['items']
# Out:
# [{'added_at': '2024-02-24T05:40:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'is_playable': True,
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'is_playable': True,
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/2EuOCirl08WxbRY2cfj4H5',
#     'id': '2EuOCirl08WxbRY2cfj4H5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739bf5280998453fee06ab1c6a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029bf5280998453fee06ab1c6a',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '2EuOCirl08WxbRY2cfj4H5'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Life in Rio'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-03-17'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2EuOCirl08WxbRY2cfj4H5'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'name': 'Life in Rio',
#   'release_date': '2023-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2EuOCirl08WxbRY2cfj4H5'},
#  {'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'name': 'REI DO BRASIL',
#   'release_date': '2023-06-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5rDznSixlUXNxJySfWQNb7'},
#  {'album_id': '7pv0piZjVlLEIYUXEQKX6x',
#   'name': 'NO GOING BACK',
#   'release_date': '2023-10-18',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/7pv0piZjVlLEIYUXEQKX6x'},
#  {'album_id': '5a9uibuVUtMag0L3Fo8gkQ',
#   'name': 'Untitled #13 (Super Slowed)',
#   'release_date': '2023-08-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5a9uibuVUtMag0L3Fo8gkQ'},
#  {'album_id': '4FRxgE6LA2UGJ5yz8diaI9',
#   'name': 'FUNKED UP',
#   'release_date': '2024-01-19',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4FRxgE6LA2UGJ5yz8diaI9'},
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '65FHTCI8EmW94W0TdWb8ja',
#   'artist_name': 'Slowboy',
#   'external_url': 'https://api.spotify.com/v1/artists/65FHTCI8EmW94W0TdWb8ja'},
#  {'artist_id': '1nccv1GNVkBdvsYi2FB5FB',
#   'artist_name': 'NUEKI',
#   'external_url': 'https://api.spotify.com/v1/artists/1nccv1GNVkBdvsYi2FB5FB'},
#  {'artist_id': '6QwlKB1hO357wh5oNuuInl',
#   'artist_name': 'Crazy Mano',
#   'external_url': 'https://api.spotify.com/v1/artists/6QwlKB1hO357wh5oNuuInl'},
#  {'artist_id': '23P2mSsBpPkfR9fTrOc1a4',
#   'artist_name': 'TOLCHONOV',
#   'external_url': 'https://api.spotify.com/v1/artists/23P2mSsBpPkfR9fTrOc1a4'},
#  {'artist_id': '3qycxIGAHj1KyoAQ6PGCO6',
#   'artist_name': 'Seek',
#   'external_url': 'https://api.spotify.com/v1/artists/3qycxIGAHj1KyoAQ6PGCO6'},
#  {'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp',
#   'artist_name': 'xxanteria',
#   'external_url': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'artist_id': '4xNuIo74R6m1eXaz7RlpZ6',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '7vtGOauV0Zz8Px5EJYm7d7',
#   'song_name': 'Life in Rio',
#   'duration_ms': 94418,
#   'url': 'https://open.spotify.com/track/7vtGOauV0Zz8Px5EJYm7d7',
#   'popularity': 68,
#   'song_added': '2024-02-24T05:40:13Z',
#   'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'artist_id': '65FHTCI8EmW94W0TdWb8ja'},
#  {'song_id': '6Seth37t5I69wFbuGFrsiG',
#   'song_name': 'REI DO BRASIL',
#   'duration_ms': 97846,
#   'url': 'https://open.spotify.com/track/6Seth37t5I69wFbuGFrsiG',
#   'popularity': 63,
#   'song_added': '2024-02-24T05:46:58Z',
#   'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'artist_id': '3qycxIGAHj1KyoAQ6PGCO6'},
#  {'song_id': '0rb7HcBkdMPp04ybHBfX41',
#   'song_name': 'BAIXO',
#   'duration_ms': 104013,
#   'url': 'https://open.spotify.com/track/0rb7HcBkdMPp04ybHBfX41',
#   'popularity': 65,
#   'song_added': '2024-02-24T05:48:13Z',
#   'album_id': '7pv0piZjVlLEIYUXEQKX6x',
#   'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'song_id': '3fC7BKJN66Tyq44x6Try2R',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                         name release_date  \
# 0  2EuOCirl08WxbRY2cfj4H5                  Life in Rio   2023-03-17
# 1  5rDznSixlUXNxJySfWQNb7                REI DO BRASIL   2023-06-02
# 2  7pv0piZjVlLEIYUXEQKX6x                NO GOING BACK   2023-10-18
# 3  5a9uibuVUtMag0L3Fo8gkQ  Untitled #13 (Super Slowed)   2023-08-09
# 4  4FRxgE6LA2UGJ5yz8diaI9                    FUNKED UP   2024-01-19
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/2EuOCirl08WxbRY...
# 1             1  https://open.spotify.com/album/5rDznSixlUXNxJy...
# 2             8  https://open.spotify.com/album/7pv0piZjVlLEIYU...
# 3             1  https://open.spotify.com/album/5a9uibuVUtMag0L...
# 4             3  https://open.spotify.com/album/4FRxgE6LA2UGJ5y...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      10 non-null     object
#  1   name          10 non-null     object
#  2   release_date  10 non-null     object
#  3   total_tracks  10 non-null     int64
#  4   url           10 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 532.0+ bytes

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                    song_name  duration_ms  \
# 0  7vtGOauV0Zz8Px5EJYm7d7                  Life in Rio        94418
# 1  6Seth37t5I69wFbuGFrsiG                REI DO BRASIL        97846
# 2  0rb7HcBkdMPp04ybHBfX41                        BAIXO       104013
# 3  3fC7BKJN66Tyq44x6Try2R  Untitled #13 (Super Slowed)       192000
# 4  4VL5XwfATZuAVTW471Wpro           FUNKED UP - SLOWED       115348
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/7vtGOauV0Zz8Px5...          68
# 1  https://open.spotify.com/track/6Seth37t5I69wFb...          63
# 2  https://open.spotify.com/track/0rb7HcBkdMPp04y...          65
# 3  https://open.spotify.com/track/3fC7BKJN66Tyq44...          65
# 4  https://open.spotify.com/track/4VL5XwfATZuAVTW...          73
#
#              song_added                album_id               artist_id
# 0  2024-02-24T05:40:13Z  2EuOCirl08WxbRY2cfj4H5  65FHTCI8EmW94W0TdWb8ja
# ...

# %%
artist_df.head()
# Out:
#                 artist_id artist_name  \
# 0  65FHTCI8EmW94W0TdWb8ja     Slowboy
# 1  1nccv1GNVkBdvsYi2FB5FB       NUEKI
# 2  6QwlKB1hO357wh5oNuuInl  Crazy Mano
# 3  23P2mSsBpPkfR9fTrOc1a4   TOLCHONOV
# 4  3qycxIGAHj1KyoAQ6PGCO6        Seek
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/65FHTCI8EmW...
# 1  https://api.spotify.com/v1/artists/1nccv1GNVkB...
# 2  https://api.spotify.com/v1/artists/6QwlKB1hO35...
# 3  https://api.spotify.com/v1/artists/23P2mSsBpPk...
# 4  https://api.spotify.com/v1/artists/3qycxIGAHj1...

# %%
album_df.head()
# Out:
#                  album_id                         name release_date  \
# 0  2EuOCirl08WxbRY2cfj4H5                  Life in Rio   2023-03-17
# 1  5rDznSixlUXNxJySfWQNb7                REI DO BRASIL   2023-06-02
# 2  7pv0piZjVlLEIYUXEQKX6x                NO GOING BACK   2023-10-18
# 3  5a9uibuVUtMag0L3Fo8gkQ  Untitled #13 (Super Slowed)   2023-08-09
# 4  4FRxgE6LA2UGJ5yz8diaI9                    FUNKED UP   2024-01-19
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/2EuOCirl08WxbRY...
# 1             1  https://open.spotify.com/album/5rDznSixlUXNxJy...
# 2             8  https://open.spotify.com/album/7pv0piZjVlLEIYU...
# 3             1  https://open.spotify.com/album/5a9uibuVUtMag0L...
# 4             3  https://open.spotify.com/album/4FRxgE6LA2UGJ5y...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])
